# %%
import psycopg2
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
user_data = pd.read_sql(
    """SELECT * FROM public.user_data""",
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

user_data
# Out:
#         user_id  gender  age country               city  exp_group       os
# 0           200       1   34  Russia          Degtyarsk          3  Android  \
# 1           201       0   37  Russia             Abakan          0  Android
# 2           202       1   17  Russia           Smolensk          4  Android
# 3           203       0   18  Russia             Moscow          1      iOS
# 4           204       0   36  Russia  Anzhero-Sudzhensk          3  Android
# ...         ...     ...  ...     ...                ...        ...      ...
# 163200   168548       0   36  Russia        Kaliningrad          4  Android
# 163201   168549       0   18  Russia               Tula          2  Android
# 163202   168550       1   41  Russia      Yekaterinburg          4  Android
# 163203   168551       0   38  Russia             Moscow          3      iOS
# 163204   168552       1   16  Russia        Ivanteyevka          4  Android
#
#          source
# 0           ads
# 1           ads
# 2           ads
# 3           ads
# 4           ads
# ...         ...
# 163200  organic
# 163201  organic
# 163202  organic
# 163203  organic
# 163204  organic
#
# [163205 rows x 8 columns]

# %%
feed_data = pd.read_sql(
    """SELECT  *
                FROM public.feed_data feed_data
                WHERE feed_data.timestamp >= to_timestamp('26.12.21', 'DD.MM.YY' ) 
                  AND feed_data.action = 'view'""",
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

feed_data
# Out:
#                   timestamp  user_id  post_id action  target
# 0       2021-12-27 21:32:56   164976     4685   view       0
# 1       2021-12-27 21:35:07   164976     6542   view       0
# 2       2021-12-27 21:35:18   164976     3040   view       0
# 3       2021-12-27 21:36:41   164976     5597   view       0
# 4       2021-12-27 21:38:27   164976      779   view       1
# ...                     ...      ...      ...    ...     ...
# 3091891 2021-12-29 14:42:37    81478     4893   view       0
# 3091892 2021-12-29 14:43:51    81478     2635   view       0
# 3091893 2021-12-29 14:45:28    81478     5015   view       0
# 3091894 2021-12-29 14:45:44    81478      154   view       0
# 3091895 2021-12-29 14:47:33    81478     5121   view       1
#
# [3091896 rows x 5 columns]

# %%
post_data = pd.read_sql(
    """SELECT * FROM public.post_text_df """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

post_data
# Out:
#       post_id                                               text     topic
# 0           1  UK economy facing major risks\n\nThe UK manufa...  business
# 1           2  Aids and climate top Davos agenda\n\nClimate c...  business
# 2           3  Asian quake hits European shares\n\nShares in ...  business
# 3           4  India power shares jump on debut\n\nShares in ...  business
# 4           5  Lacroix label bought by US firm\n\nLuxury good...  business
# ...       ...                                                ...       ...
# 7018     7315  OK, I would not normally watch a Farrelly brot...     movie
# 7019     7316  I give this movie 2 stars purely because of it...     movie
# 7020     7317  I cant believe this film was allowed to be mad...     movie
# 7021     7318  The version I saw of this film was the Blockbu...     movie
# 7022     7319  Piece of subtle art. Maybe a masterpiece. Doub...     movie
#
# [7023 rows x 3 columns]

# %%
def text_column_processing(X):    
        ## Метод TF-IDF
        from sklearn.feature_extraction.text import TfidfVectorizer
        tf_idf = TfidfVectorizer()
        text_tf_idf = tf_idf.fit_transform(X['text'])

        ## Метод главных компонет сверху TF-IDF
        from sklearn.decomposition import PCA
        pca = PCA(n_components = 3)
        PCA_post_text_dataset = pca.fit_transform(text_tf_idf.toarray())
        PCA_post_text_dataset = pd.DataFrame(PCA_post_text_dataset, 
                                             columns=['PCA_text_1', 'PCA_text_2', 'PCA_text_3'], 
                                             index=X['post_id'])
        return PCA_post_text_dataset

# %%
PCA_post_text_dataset = text_column_processing(post_data[['post_id', 'text']].drop_duplicates(subset='post_id'))

# %%
PCA_post_text_dataset
# Out:
#          PCA_text_1  PCA_text_2  PCA_text_3
# post_id
# 1         -0.118109   -0.202089   -0.091933
# 2         -0.142662   -0.224652   -0.000819
# 3         -0.104280   -0.152657   -0.088866
# 4         -0.001531   -0.127432   -0.054625
# 5          0.055888   -0.104884   -0.004086
# ...             ...         ...         ...
# 7315      -0.076983    0.210305    0.128411
# 7316      -0.086584    0.131223    0.072674
# 7317       0.017890    0.105220   -0.016941
# 7318      -0.135336    0.119797    0.012214
# 7319       0.009964    0.042797   -0.090274
#
# [7023 rows x 3 columns]

# %%
post_PCA = pd.merge(
    PCA_post_text_dataset,
    post_data,
    on='post_id',
    how='left'
)

post_PCA
# Out:
#       post_id  PCA_text_1  PCA_text_2  PCA_text_3
# 0           1   -0.118109   -0.202089   -0.091933  \
# 1           2   -0.142662   -0.224652   -0.000819
# 2           3   -0.104280   -0.152657   -0.088866
# 3           4   -0.001531   -0.127432   -0.054625
# 4           5    0.055888   -0.104884   -0.004086
# ...       ...         ...         ...         ...
# 7018     7315   -0.076983    0.210305    0.128411
# 7019     7316   -0.086584    0.131223    0.072674
# 7020     7317    0.017890    0.105220   -0.016941
# 7021     7318   -0.135336    0.119797    0.012214
# 7022     7319    0.009964    0.042797   -0.090274
#
#                                                    text     topic
# 0     UK economy facing major risks\n\nThe UK manufa...  business
# 1     Aids and climate top Davos agenda\n\nClimate c...  business
# 2     Asian quake hits European shares\n\nShares in ...  business
# 3     India power shares jump on debut\n\nShares in ...  business
# 4     Lacroix label bought by US firm\n\nLuxury good...  business
# ...                                                 ...       ...
# 7018  OK, I would not normally watch a Farrelly brot...     movie
# 7019  I give this movie 2 stars purely because of it...     movie
# 7020  I cant believe this film was allowed to be mad...     movie
# 7021  The version I saw of this film was the Blockbu...     movie
# 7022  Piece of subtle art. Maybe a masterpiece. Doub...     movie
#
# [7023 rows x 6 columns]

# %% [markdown]
# ### Контентный подход

# %%
#Удаляем столбец action тк в нем всего одно значение
feed_data.drop('action', axis=1, inplace = True)
feed_data
# Out:
#                   timestamp  user_id  post_id  target
# 0       2021-12-27 21:32:56   164976     4685       0
# 1       2021-12-27 21:35:07   164976     6542       0
# 2       2021-12-27 21:35:18   164976     3040       0
# 3       2021-12-27 21:36:41   164976     5597       0
# 4       2021-12-27 21:38:27   164976      779       1
# ...                     ...      ...      ...     ...
# 3091891 2021-12-29 14:42:37    81478     4893       0
# 3091892 2021-12-29 14:43:51    81478     2635       0
# 3091893 2021-12-29 14:45:28    81478     5015       0
# 3091894 2021-12-29 14:45:44    81478      154       0
# 3091895 2021-12-29 14:47:33    81478     5121       1
#
# [3091896 rows x 4 columns]

# %%
feed_data['timestamp'] = pd.to_datetime(feed_data['timestamp'])
feed_data['hour_of_action'] = feed_data['timestamp'].dt.hour

# %%
feed_data
# Out:
#                   timestamp  user_id  post_id  target  hour_of_action
# 0       2021-12-27 21:32:56   164976     4685       0              21
# 1       2021-12-27 21:35:07   164976     6542       0              21
# 2       2021-12-27 21:35:18   164976     3040       0              21
# 3       2021-12-27 21:36:41   164976     5597       0              21
# 4       2021-12-27 21:38:27   164976      779       1              21
# ...                     ...      ...      ...     ...             ...
# 3091891 2021-12-29 14:42:37    81478     4893       0              14
# 3091892 2021-12-29 14:43:51    81478     2635       0              14
# 3091893 2021-12-29 14:45:28    81478     5015       0              14
# 3091894 2021-12-29 14:45:44    81478      154       0              14
# 3091895 2021-12-29 14:47:33    81478     5121       1              14
#
# [3091896 rows x 5 columns]

# %%
df = pd.merge(
    feed_data,
    user_data,
    on='user_id',
    how='left'
)

df
# Out:
#                   timestamp  user_id  post_id  target  hour_of_action  gender
# 0       2021-12-27 21:32:56   164976     4685       0              21       1  \
# 1       2021-12-27 21:35:07   164976     6542       0              21       1
# 2       2021-12-27 21:35:18   164976     3040       0              21       1
# 3       2021-12-27 21:36:41   164976     5597       0              21       1
# 4       2021-12-27 21:38:27   164976      779       1              21       1
# ...                     ...      ...      ...     ...             ...     ...
# 3091891 2021-12-29 14:42:37    81478     4893       0              14       0
# 3091892 2021-12-29 14:43:51    81478     2635       0              14       0
# 3091893 2021-12-29 14:45:28    81478     5015       0              14       0
# 3091894 2021-12-29 14:45:44    81478      154       0              14       0
# 3091895 2021-12-29 14:47:33    81478     5121       1              14       0
#
#          age country        city  exp_group       os   source
# 0         47  Russia  Novozybkov          0      iOS  organic
# 1         47  Russia  Novozybkov          0      iOS  organic
# 2         47  Russia  Novozybkov          0      iOS  organic
# 3         47  Russia  Novozybkov          0      iOS  organic
# 4         47  Russia  Novozybkov          0      iOS  organic
# ...      ...     ...         ...        ...      ...      ...
# 3091891   21  Russia   Lyudinovo          2  Android      ads
# 3091892   21  Russia   Lyudinovo          2  Android      ads
# 3091893   21  Russia   Lyudinovo          2  Android      ads
# 3091894   21  Russia   Lyudinovo          2  Android      ads
# 3091895   21  Russia   Lyudinovo          2  Android      ads
#
# [3091896 rows x 12 columns]

# %%
df = pd.merge(
    df,
    post_PCA,
    on='post_id',
    how='left'
)

df.head()
# Out:
#             timestamp  user_id  post_id  target  hour_of_action  gender  age
# 0 2021-12-27 21:32:56   164976     4685       0              21       1   47  \
# 1 2021-12-27 21:35:07   164976     6542       0              21       1   47
# 2 2021-12-27 21:35:18   164976     3040       0              21       1   47
# 3 2021-12-27 21:36:41   164976     5597       0              21       1   47
# 4 2021-12-27 21:38:27   164976      779       1              21       1   47
#
#   country        city  exp_group   os   source  PCA_text_1  PCA_text_2
# 0  Russia  Novozybkov          0  iOS  organic   -0.076086    0.151342  \
# 1  Russia  Novozybkov          0  iOS  organic   -0.189369    0.022530
# 2  Russia  Novozybkov          0  iOS  organic    0.252496   -0.004799
# 3  Russia  Novozybkov          0  iOS  organic   -0.182676   -0.009720
# 4  Russia  Novozybkov          0  iOS  organic   -0.045372   -0.089701
#
#    PCA_text_3                                               text
# 0    0.014963  I cannot see why anyone would make such a movi...  \
# 1    0.004020  I know that there are some purists out there w...
# 2   -0.008169  Pierre Dufour joins YourTV to discuss the @Cor...
# 3   -0.087353  Hollywood North is an euphemism from the movie...
# 4   -0.042046  Branson show flops on US screens\n\nEntreprene...
#
#            topic
# 0          movie
# 1          movie
# 2          covid
# 3          movie
# 4  entertainment

# %%
df
# Out:
#                   timestamp  user_id  post_id  target  hour_of_action  gender
# 0       2021-12-27 21:32:56   164976     4685       0              21       1  \
# 1       2021-12-27 21:35:07   164976     6542       0              21       1
# 2       2021-12-27 21:35:18   164976     3040       0              21       1
# 3       2021-12-27 21:36:41   164976     5597       0              21       1
# 4       2021-12-27 21:38:27   164976      779       1              21       1
# ...                     ...      ...      ...     ...             ...     ...
# 3091891 2021-12-29 14:42:37    81478     4893       0              14       0
# 3091892 2021-12-29 14:43:51    81478     2635       0              14       0
# 3091893 2021-12-29 14:45:28    81478     5015       0              14       0
# 3091894 2021-12-29 14:45:44    81478      154       0              14       0
# 3091895 2021-12-29 14:47:33    81478     5121       1              14       0
#
#          age country        city  exp_group       os   source  PCA_text_1
# 0         47  Russia  Novozybkov          0      iOS  organic   -0.076086  \
# 1         47  Russia  Novozybkov          0      iOS  organic   -0.189369
# 2         47  Russia  Novozybkov          0      iOS  organic    0.252496
# 3         47  Russia  Novozybkov          0      iOS  organic   -0.182676
# 4         47  Russia  Novozybkov          0      iOS  organic   -0.045372
# ...      ...     ...         ...        ...      ...      ...         ...
# 3091891   21  Russia   Lyudinovo          2  Android      ads   -0.189456
# 3091892   21  Russia   Lyudinovo          2  Android      ads    0.228477
# 3091893   21  Russia   Lyudinovo          2  Android      ads   -0.129867
# 3091894   21  Russia   Lyudinovo          2  Android      ads   -0.066543
# 3091895   21  Russia   Lyudinovo          2  Android      ads   -0.201603
#
#          PCA_text_2  PCA_text_3
# 0          0.151342    0.014963  \
# 1          0.022530    0.004020
# 2         -0.004799   -0.008169
# 3         -0.009720   -0.087353
# 4         -0.089701   -0.042046
# ...             ...         ...
# 3091891    0.108917   -0.030894
# 3091892   -0.008134    0.016219
# 3091893    0.064373    0.002171
# 3091894   -0.174295   -0.037492
# 3091895    0.073049   -0.019803
#
#                                                       text          topic
# 0        I cannot see why anyone would make such a movi...          movie
# 1        I know that there are some purists out there w...          movie
# 2        Pierre Dufour joins YourTV to discuss the @Cor...          covid
# 3        Hollywood North is an euphemism from the movie...          movie
# 4        Branson show flops on US screens\n\nEntreprene...  entertainment
# ...                                                    ...            ...
# 3091891  I heard about this movie when watching VH1s 10...          movie
# 3091892  Please please now is the time to put politics ...          covid
# 3091893  Although I like Kurt Vonnegut, Im not particul...          movie
# 3091894  Economy strong in election year\n\nUK business...       business
# 3091895  How The Grinch Stole Christmas instantly stole...          movie
#
# [3091896 rows x 17 columns]

# %%
#While we delete column "Text", we'll deal with it later
df.drop('text', axis=1, inplace = True)
df
# Out:
#                   timestamp  user_id  post_id  target  hour_of_action  gender
# 0       2021-12-27 21:32:56   164976     4685       0              21       1  \
# 1       2021-12-27 21:35:07   164976     6542       0              21       1
# 2       2021-12-27 21:35:18   164976     3040       0              21       1
# 3       2021-12-27 21:36:41   164976     5597       0              21       1
# 4       2021-12-27 21:38:27   164976      779       1              21       1
# ...                     ...      ...      ...     ...             ...     ...
# 3091891 2021-12-29 14:42:37    81478     4893       0              14       0
# 3091892 2021-12-29 14:43:51    81478     2635       0              14       0
# 3091893 2021-12-29 14:45:28    81478     5015       0              14       0
# 3091894 2021-12-29 14:45:44    81478      154       0              14       0
# 3091895 2021-12-29 14:47:33    81478     5121       1              14       0
#
#          age country        city  exp_group       os   source  PCA_text_1
# 0         47  Russia  Novozybkov          0      iOS  organic   -0.076086  \
# 1         47  Russia  Novozybkov          0      iOS  organic   -0.189369
# 2         47  Russia  Novozybkov          0      iOS  organic    0.252496
# 3         47  Russia  Novozybkov          0      iOS  organic   -0.182676
# 4         47  Russia  Novozybkov          0      iOS  organic   -0.045372
# ...      ...     ...         ...        ...      ...      ...         ...
# 3091891   21  Russia   Lyudinovo          2  Android      ads   -0.189456
# 3091892   21  Russia   Lyudinovo          2  Android      ads    0.228477
# 3091893   21  Russia   Lyudinovo          2  Android      ads   -0.129867
# 3091894   21  Russia   Lyudinovo          2  Android      ads   -0.066543
# 3091895   21  Russia   Lyudinovo          2  Android      ads   -0.201603
#
#          PCA_text_2  PCA_text_3          topic
# 0          0.151342    0.014963          movie
# 1          0.022530    0.004020          movie
# 2         -0.004799   -0.008169          covid
# 3         -0.009720   -0.087353          movie
# 4         -0.089701   -0.042046  entertainment
# ...             ...         ...            ...
# 3091891    0.108917   -0.030894          movie
# 3091892   -0.008134    0.016219          covid
# 3091893    0.064373    0.002171          movie
# 3091894   -0.174295   -0.037492       business
# 3091895    0.073049   -0.019803          movie
#
# [3091896 rows x 16 columns]

# %%
categorical_columns = df.loc[:,df.dtypes==np.object_].columns
categorical_columns
# Out:
# Index(['country', 'city', 'os', 'source', 'topic'], dtype='object')

# %%
categorical_columns_user = user_data.loc[:,user_data.dtypes==np.object_].columns
categorical_columns_user
# Out:
# Index(['country', 'city', 'os', 'source'], dtype='object')

# %%
df.describe(include='object')
# Out:
#         country     city       os   source    topic
# count   3091896  3091896  3091896  3091896  3091896
# unique       11     3341        2        2        7
# top      Russia   Moscow  Android      ads    movie
# freq    2711678   416512  2009608  1926118  1144766

# %%
df['target'].value_counts()
# Out:
# target
# 0    2667879
# 1     424017
# Name: count, dtype: int64

# %%
### Функция для multiclass encoding'а
### Пока откладываем этот метод
def encode_multiclass_target(df, category, target='target'):
    df = df[[category, target]].copy()
    
    target_dummies = pd.get_dummies(df[target], 
                                    prefix=category, 
                                    drop_first=True)
    
    df = pd.concat((df, target_dummies), axis=1)
    
    for tg in target_dummies.columns:
        
        df[tg] = df.groupby(category)[tg].transform("mean")
    
    return df.drop(category, axis=1)

# %%
for col in categorical_columns:
    if df[col].nunique() < 8:
        one_hot = pd.get_dummies(df[col], prefix=col, drop_first=True)     
        df = pd.concat((df.drop(col, axis=1), one_hot), axis=1)
    else:
        mean_target = encode_multiclass_target(df, col).drop("target", axis=1)
        df = pd.concat((df.drop(col, axis=1), mean_target), axis=1)

# %%
df['user_id'].nunique()
# Out:
# 80952

# %%
df
# Out:
#                   timestamp  user_id  post_id  target  hour_of_action  gender
# 0       2021-12-27 21:32:56   164976     4685       0              21       1  \
# 1       2021-12-27 21:35:07   164976     6542       0              21       1
# 2       2021-12-27 21:35:18   164976     3040       0              21       1
# 3       2021-12-27 21:36:41   164976     5597       0              21       1
# 4       2021-12-27 21:38:27   164976      779       1              21       1
# ...                     ...      ...      ...     ...             ...     ...
# 3091891 2021-12-29 14:42:37    81478     4893       0              14       0
# 3091892 2021-12-29 14:43:51    81478     2635       0              14       0
# 3091893 2021-12-29 14:45:28    81478     5015       0              14       0
# 3091894 2021-12-29 14:45:44    81478      154       0              14       0
# 3091895 2021-12-29 14:47:33    81478     5121       1              14       0
#
#          age  exp_group  PCA_text_1  PCA_text_2  ...  country_1    city_1
# 0         47          0   -0.076086    0.151342  ...   0.129955  0.154275  \
# 1         47          0   -0.189369    0.022530  ...   0.129955  0.154275
# 2         47          0    0.252496   -0.004799  ...   0.129955  0.154275
# 3         47          0   -0.182676   -0.009720  ...   0.129955  0.154275
# 4         47          0   -0.045372   -0.089701  ...   0.129955  0.154275
# ...      ...        ...         ...         ...  ...        ...       ...
# 3091891   21          2   -0.189456    0.108917  ...   0.129955  0.114047
# 3091892   21          2    0.228477   -0.008134  ...   0.129955  0.114047
# 3091893   21          2   -0.129867    0.064373  ...   0.129955  0.114047
# 3091894   21          2   -0.066543   -0.174295  ...   0.129955  0.114047
# 3091895   21          2   -0.201603    0.073049  ...   0.129955  0.114047
#
#          os_iOS  source_organic  topic_covid  topic_entertainment
# 0          True            True        False                False  \
# 1          True            True        False                False
# 2          True            True         True                False
# 3          True            True        False                False
# 4          True            True        False                 True
# ...         ...             ...          ...                  ...
# 3091891   False           False        False                False
# 3091892   False           False         True                False
# 3091893   False           False        False                False
# 3091894   False           False        False                False
# 3091895   False           False        False                False
#
#          topic_movie  topic_politics  topic_sport  topic_tech
# 0               True           False        False       False
# 1               True           False        False       False
# 2              False           False        False       False
# 3               True           False        False       False
# 4              False           False        False       False
# ...              ...             ...          ...         ...
# 3091891         True           False        False       False
# 3091892        False           False        False       False
# 3091893         True           False        False       False
# 3091894        False           False        False       False
# 3091895         True           False        False       False
#
# [3091896 rows x 21 columns]

# %%
user_count_views = df.groupby('user_id').size()
user_means = df.groupby('user_id')['target'].sum()

# %%
df['userViews'] = df['user_id'].map(user_count_views)
df['userMeans'] = df['user_id'].map(user_means)

# %%
### Разделим выборку на train-test

df_witout_time = df.drop(['timestamp'], axis=1)

# %%
from sklearn.model_selection import train_test_split
X = df.drop('target', axis=1)
y = df['target']

# %%
#Выборку делим на train-test по времени
#Train все что было за 3 часа до, в тест последние 3 часа действий
d = df['timestamp'].max() - pd.Timedelta(hours=3) 
X_test, X_train = X[X.timestamp >= d], X[X.timestamp < d]
y_test, y_train = y[y.index.isin(X_test.index)], y[y.index.isin(X_train.index)]
X_train = X_train.drop(['user_id','timestamp'], axis=1)

# %%
X_test_without_id = X_test.drop(['user_id','timestamp'], axis=1)

# %%
X_test_without_id
# Out:
#          post_id  hour_of_action  gender  age  exp_group  PCA_text_1
# 1744         671              21       1   33          4   -0.053187  \
# 1745          59              21       1   33          4   -0.004492
# 1746        6441              21       1   33          4   -0.155520
# 1747        2528              21       1   33          4    0.320484
# 1748        6165              21       1   33          4   -0.061661
# ...          ...             ...     ...  ...        ...         ...
# 3091012     2770              22       1   43          0    0.214111
# 3091013     1264              22       1   43          0   -0.198764
# 3091014     1468              22       1   43          0   -0.041592
# 3091015      867              22       1   43          0   -0.044761
# 3091016     1654              22       1   43          0   -0.184471
#
#          PCA_text_2  PCA_text_3  country_1    city_1  os_iOS  source_organic
# 1744      -0.083534    0.067097   0.129955  0.170186   False           False  \
# 1745      -0.123222   -0.046583   0.129955  0.170186   False           False
# 1746       0.113802    0.073984   0.129955  0.170186   False           False
# 1747      -0.005197   -0.010041   0.129955  0.170186   False           False
# 1748       0.049173   -0.022976   0.129955  0.170186   False           False
# ...             ...         ...        ...       ...     ...             ...
# 3091012   -0.008100    0.050154   0.129955  0.161501   False            True
# 3091013   -0.207595    0.009276   0.129955  0.161501   False            True
# 3091014   -0.111914    0.036032   0.129955  0.161501   False            True
# 3091015   -0.069976   -0.113312   0.129955  0.161501   False            True
# 3091016   -0.066435    0.120055   0.129955  0.161501   False            True
#
#          topic_covid  topic_entertainment  topic_movie  topic_politics
# 1744           False                 True        False           False  \
# 1745           False                False        False           False
# 1746           False                False         True           False
# 1747            True                False        False           False
# 1748           False                False         True           False
# ...              ...                  ...          ...             ...
# 3091012         True                False        False           False
# 3091013        False                False        False            True
# 3091014        False                False        False           False
# 3091015        False                 True        False           False
# 3091016        False                False        False           False
#
#          topic_sport  topic_tech  userViews  userMeans
# 1744           False       False         29          6
# 1745           False       False         29          6
# 1746           False       False         29          6
# 1747           False       False         29          6
# 1748           False       False         29          6
# ...              ...         ...        ...        ...
# 3091012        False       False         58          9
# 3091013        False       False         58          9
# 3091014         True       False         58          9
# 3091015        False       False         58          9
# 3091016         True       False         58          9
#
# [117768 rows x 20 columns]

# %%
y_train.value_counts()
# Out:
# target
# 0    2568225
# 1     405903
# Name: count, dtype: int64

# %%
from catboost import CatBoostClassifier, Pool
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
pipe = Pipeline([
                 ("scaler", StandardScaler()),  
                 ("cat_boost_estimator",  CatBoostClassifier()),
                 ])
pipe.fit(X_train, y_train)
# Out:
# Learning rate set to 0.313371
# 0:	learn: 0.5061510	total: 265ms	remaining: 4m 25s
# 1:	learn: 0.4314278	total: 442ms	remaining: 3m 40s
# 2:	learn: 0.4002509	total: 619ms	remaining: 3m 25s
# 3:	learn: 0.3851048	total: 781ms	remaining: 3m 14s
# 4:	learn: 0.3783883	total: 949ms	remaining: 3m 8s
# 5:	learn: 0.3748582	total: 1.08s	remaining: 2m 59s
# 6:	learn: 0.3718205	total: 1.25s	remaining: 2m 57s
# 7:	learn: 0.3709592	total: 1.4s	remaining: 2m 53s
# 8:	learn: 0.3691116	total: 1.55s	remaining: 2m 50s
# 9:	learn: 0.3686953	total: 1.68s	remaining: 2m 46s
# 10:	learn: 0.3684800	total: 1.82s	remaining: 2m 43s
# 11:	learn: 0.3676339	total: 1.97s	remaining: 2m 41s
# 12:	learn: 0.3672954	total: 2.11s	remaining: 2m 40s
# 13:	learn: 0.3670275	total: 2.25s	remaining: 2m 38s
# 14:	learn: 0.3669201	total: 2.39s	remaining: 2m 36s
# 15:	learn: 0.3668019	total: 2.52s	remaining: 2m 35s
# 16:	learn: 0.3664138	total: 2.66s	remaining: 2m 33s
# 17:	learn: 0.3661583	total: 2.79s	remaining: 2m 32s
# 18:	learn: 0.3660806	total: 2.94s	remaining: 2m 31s
# 19:	learn: 0.3660354	total: 3.08s	remaining: 2m 30s
# 20:	learn: 0.3659913	total: 3.21s	remaining: 2m 29s
# 21:	learn: 0.3657535	total: 3.35s	remaining: 2m 28s
# 22:	learn: 0.3655634	total: 3.5s	remaining: 2m 28s
# 23:	learn: 0.3655294	total: 3.65s	remaining: 2m 28s
# 24:	learn: 0.3653723	total: 3.79s	remaining: 2m 27s
# 25:	learn: 0.3653367	total: 3.94s	remaining: 2m 27s
# 26:	learn: 0.3651753	total: 4.08s	remaining: 2m 26s
# 396:	learn: 0.3582529	total: 59.6s	remaining: 1m 30s
# 397:	learn: 0.3582462	total: 59.7s	remaining: 1m 30s
# 398:	learn: 0.3582269	total: 59.9s	remaining: 1m 30s
# 399:	learn: 0.3582189	total: 1m	remaining: 1m 30s
# 400:	learn: 0.3582128	total: 1m	remaining: 1m 29s
# 401:	learn: 0.3582069	total: 1m	remaining: 1m 29s
# 402:	learn: 0.3582000	total: 1m	remaining: 1m 29s
# 403:	learn: 0.3581905	total: 1m	remaining: 1m 29s
# 404:	learn: 0.3581819	total: 1m	remaining: 1m 29s
# 405:	learn: 0.3581744	total: 1m	remaining: 1m 29s
# 406:	learn: 0.3581670	total: 1m 1s	remaining: 1m 29s
# 407:	learn: 0.3581614	total: 1m 1s	remaining: 1m 28s
# 408:	learn: 0.3581561	total: 1m 1s	remaining: 1m 28s
# 409:	learn: 0.3581413	total: 1m 1s	remaining: 1m 28s
# 410:	learn: 0.3581332	total: 1m 1s	remaining: 1m 28s
# 411:	learn: 0.3581201	total: 1m 1s	remaining: 1m 28s
# 412:	learn: 0.3581106	total: 1m 2s	remaining: 1m 28s
# 413:	learn: 0.3581030	total: 1m 2s	remaining: 1m 28s
# 414:	learn: 0.3580976	total: 1m 2s	remaining: 1m 27s
# 415:	learn: 0.3580899	total: 1m 2s	remaining: 1m 27s
# 416:	learn: 0.3580763	total: 1m 2s	remaining: 1m 27s
# 417:	learn: 0.3580597	total: 1m 2s	remaining: 1m 27s
# 418:	learn: 0.3580430	total: 1m 2s	remaining: 1m 27s
# 419:	learn: 0.3580362	total: 1m 3s	remaining: 1m 27s
# 420:	learn: 0.3580174	total: 1m 3s	remaining: 1m 26s
# 421:	learn: 0.3580052	total: 1m 3s	remaining: 1m 26s
# 422:	learn: 0.3579958	total: 1m 3s	remaining: 1m 26s
# 423:	learn: 0.3579884	total: 1m 3s	remaining: 1m 26s
# 424:	learn: 0.3579809	total: 1m 3s	remaining: 1m 26s
# 425:	learn: 0.3579726	total: 1m 4s	remaining: 1m 26s
# 426:	learn: 0.3579627	total: 1m 4s	remaining: 1m 26s
# 427:	learn: 0.3579574	total: 1m 4s	remaining: 1m 25s
# 428:	learn: 0.3579496	total: 1m 4s	remaining: 1m 25s
# 429:	learn: 0.3579386	total: 1m 4s	remaining: 1m 25s
# 430:	learn: 0.3579296	total: 1m 4s	remaining: 1m 25s
# 431:	learn: 0.3579096	total: 1m 4s	remaining: 1m 25s
# 432:	learn: 0.3579015	total: 1m 5s	remaining: 1m 25s
# 433:	learn: 0.3578936	total: 1m 5s	remaining: 1m 25s
# 434:	learn: 0.3578888	total: 1m 5s	remaining: 1m 24s
# 435:	learn: 0.3578812	total: 1m 5s	remaining: 1m 24s
# 436:	learn: 0.3578738	total: 1m 5s	remaining: 1m 24s
# 437:	learn: 0.3578663	total: 1m 5s	remaining: 1m 24s
# 438:	learn: 0.3578542	total: 1m 6s	remaining: 1m 24s
# 439:	learn: 0.3578482	total: 1m 6s	remaining: 1m 24s
# 440:	learn: 0.3578421	total: 1m 6s	remaining: 1m 24s
# 530:	learn: 0.3569452	total: 1m 20s	remaining: 1m 11s
# 531:	learn: 0.3569386	total: 1m 21s	remaining: 1m 11s
# 532:	learn: 0.3569345	total: 1m 21s	remaining: 1m 11s
# 533:	learn: 0.3569283	total: 1m 21s	remaining: 1m 11s
# 534:	learn: 0.3569213	total: 1m 21s	remaining: 1m 10s
# 535:	learn: 0.3569078	total: 1m 21s	remaining: 1m 10s
# 536:	learn: 0.3569029	total: 1m 21s	remaining: 1m 10s
# 537:	learn: 0.3568957	total: 1m 22s	remaining: 1m 10s
# 538:	learn: 0.3568877	total: 1m 22s	remaining: 1m 10s
# 539:	learn: 0.3568772	total: 1m 22s	remaining: 1m 10s
# 540:	learn: 0.3568695	total: 1m 22s	remaining: 1m 10s
# 541:	learn: 0.3568622	total: 1m 22s	remaining: 1m 9s
# 542:	learn: 0.3568517	total: 1m 22s	remaining: 1m 9s
# 543:	learn: 0.3568436	total: 1m 23s	remaining: 1m 9s
# 544:	learn: 0.3568360	total: 1m 23s	remaining: 1m 9s
# 545:	learn: 0.3568235	total: 1m 23s	remaining: 1m 9s
# 546:	learn: 0.3568137	total: 1m 23s	remaining: 1m 9s
# 547:	learn: 0.3568071	total: 1m 23s	remaining: 1m 9s
# 548:	learn: 0.3568003	total: 1m 23s	remaining: 1m 8s
# 549:	learn: 0.3567939	total: 1m 23s	remaining: 1m 8s
# 550:	learn: 0.3567912	total: 1m 24s	remaining: 1m 8s
# 551:	learn: 0.3567794	total: 1m 24s	remaining: 1m 8s
# 552:	learn: 0.3567761	total: 1m 24s	remaining: 1m 8s
# 553:	learn: 0.3567663	total: 1m 24s	remaining: 1m 8s
# 554:	learn: 0.3567592	total: 1m 24s	remaining: 1m 7s
# 555:	learn: 0.3567529	total: 1m 24s	remaining: 1m 7s
# 556:	learn: 0.3567365	total: 1m 25s	remaining: 1m 7s
# 557:	learn: 0.3567317	total: 1m 25s	remaining: 1m 7s
# 558:	learn: 0.3567245	total: 1m 25s	remaining: 1m 7s
# 559:	learn: 0.3567184	total: 1m 25s	remaining: 1m 7s
# 560:	learn: 0.3567059	total: 1m 25s	remaining: 1m 7s
# 561:	learn: 0.3566982	total: 1m 25s	remaining: 1m 6s
# 562:	learn: 0.3566926	total: 1m 26s	remaining: 1m 6s
# 563:	learn: 0.3566854	total: 1m 26s	remaining: 1m 6s
# 564:	learn: 0.3566775	total: 1m 26s	remaining: 1m 6s
# 565:	learn: 0.3566718	total: 1m 26s	remaining: 1m 6s
# 566:	learn: 0.3566664	total: 1m 26s	remaining: 1m 6s
# 567:	learn: 0.3566558	total: 1m 26s	remaining: 1m 6s
# 568:	learn: 0.3566433	total: 1m 27s	remaining: 1m 5s
# 569:	learn: 0.3566313	total: 1m 27s	remaining: 1m 5s
# 570:	learn: 0.3566259	total: 1m 27s	remaining: 1m 5s
# 571:	learn: 0.3566206	total: 1m 27s	remaining: 1m 5s
# 572:	learn: 0.3566078	total: 1m 27s	remaining: 1m 5s
# 573:	learn: 0.3565994	total: 1m 27s	remaining: 1m 5s
# 988:	learn: 0.3535847	total: 2m 37s	remaining: 1.75s
# 989:	learn: 0.3535794	total: 2m 37s	remaining: 1.59s
# 990:	learn: 0.3535748	total: 2m 37s	remaining: 1.43s
# 991:	learn: 0.3535718	total: 2m 37s	remaining: 1.27s
# 992:	learn: 0.3535670	total: 2m 38s	remaining: 1.11s
# 993:	learn: 0.3535603	total: 2m 38s	remaining: 955ms
# 994:	learn: 0.3535552	total: 2m 38s	remaining: 796ms
# 995:	learn: 0.3535487	total: 2m 38s	remaining: 637ms
# 996:	learn: 0.3535436	total: 2m 38s	remaining: 477ms
# 997:	learn: 0.3535344	total: 2m 38s	remaining: 318ms
# 998:	learn: 0.3535246	total: 2m 39s	remaining: 159ms
# 999:	learn: 0.3535195	total: 2m 39s	remaining: 0us
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('cat_boost_estimator',
#                  <catboost.core.CatBoostClassifier object at 0x2e4a56f10>)])

# %%
X_test_without_id.columns
# Out:
# Index(['gender', 'age', 'exp_group', 'post_id', 'hour_of_action',
#        'minute_of_action', 'PCA_text_1', 'PCA_text_2', 'PCA_text_3',
#        'userViews', 'userMeans', 'country_1.0', 'city_1.0', 'os_iOS',
#        'source_organic', 'topic_covid', 'topic_entertainment', 'topic_movie',
#        'topic_politics', 'topic_sport', 'topic_tech'],
#       dtype='object')

# %%
from sklearn.metrics import classification_report
y_pred = pipe.predict(X_test_without_id)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92     99654
#            1       0.39      0.01      0.02     18114
#
#     accuracy                           0.85    117768
#    macro avg       0.62      0.50      0.47    117768
# weighted avg       0.78      0.85      0.78    117768

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

y_pred = pipe.predict(X_test_without_id)
y_pred_proba = pipe.predict_proba(X_test_without_id)[:, 1] # вероятности класса 1

print(f'balanced_accuracy = {balanced_accuracy_score(y_test, y_pred)}')
print(f'accuracy = {accuracy_score(y_test, y_pred)}')
print(f'f1_score = {f1_score(y_test, y_pred)}')
# Out:
# balanced_accuracy = 0.5040229472211679
# accuracy = 0.8451616737993343
# f1_score = 0.02198980960042907

# %%
### При расчете исключаю пользователей, которые не ставили хотя бы одного лайка
X_test_ = X_test[['user_id','post_id']]

X_test_['pred'] = y_pred
X_test_['pred_proba'] = y_pred_proba
X_test_['target'] = y_test

hitrate_list = []
user_without_likes = []
unique_user_count = 0

for user in X_test_['user_id'].unique():
    # Выбираем строки с конкретным пользователем
    part = X_test_[X_test_['user_id']==user]
    
    # Вычисляем, есть ли у пользователя хотя бы 1 лайк
    temp = [1 if part['target'].sum()==0 else 0]
    
    # если у пользователя нет хотя бы 1-ого лайка,
    # то не включаем его в расчет метрики
    if np.sum(temp)==1:
        user_without_likes.append(temp)
        continue
    else:
        # сортируем посты строки по вероятности класса 1 (лайка)
        # выбираем 5 строк с наибольшей вероятностью лайка
        part = part.sort_values(by='pred_proba', ascending=False).head(5)
        # если правильно предсказан хотя бы 1 пост,
        # то ставим 1, иначе 0
        hitrate = [1 if (part['target']).sum() > 0 else 0]   
        
        hitrate_list.append(hitrate)
        unique_user_count += 1
    
print(f"Среднее hitrate по пользователям из теста: {np.round(np.sum(hitrate_list)/unique_user_count, 2)}")
print(f"Доля пользователей без лайков: {np.round(np.sum(user_without_likes)/X_test_['user_id'].unique().shape[0], 2)}")
# Out:
# /var/folders/w1/w_59zgln13d9rzr047_dbkww0000gn/T/ipykernel_4396/3729158146.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_['pred'] = y_pred
# /var/folders/w1/w_59zgln13d9rzr047_dbkww0000gn/T/ipykernel_4396/3729158146.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_['pred_proba'] = y_pred_proba
# /var/folders/w1/w_59zgln13d9rzr047_dbkww0000gn/T/ipykernel_4396/3729158146.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_['target'] = y_test
# Среднее hitrate по пользователям из теста: 0.7
# Доля пользователей без лайков: 0.14

# %%
import pickle
filename = 'Models/catboost_model_2.pkl'
pickle.dump(pipe, open(filename, 'wb'))

# %%
import os
from catboost import CatBoostClassifier
import pickle

def get_model_path(path: str) -> str:
    if os.environ.get("IS_LMS") == "1":  # проверяем где выполняется код в лмс, или локально. Немного магии
        MODEL_PATH = '/workdir/user_input/model'
    else:
        MODEL_PATH = path
    return MODEL_PATH

def load_models():
    model_path = get_model_path("./catboost_model.pkl")
    loaded_model = pickle.load(open(model_path, 'rb'))
    loaded_model.predict(X_train)# пример как можно загружать модели

# %%
load_models()

# %%
one_hot = pd.get_dummies(post_data['topic'], prefix='topic', drop_first=True)     
df_post = pd.concat((post_data.drop('topic', axis=1), one_hot), axis=1)

# %%
def text_column_processing(X):    
        ## Метод TF-IDF
        from sklearn.feature_extraction.text import TfidfVectorizer
        tf_idf = TfidfVectorizer()
        text_tf_idf = tf_idf.fit_transform(X['text'])

        ## Метод главных компонет сверху TF-IDF
        from sklearn.decomposition import PCA
        pca = PCA(n_components = 3)
        PCA_post_text_dataset = pca.fit_transform(text_tf_idf.toarray())
        PCA_post_text_dataset = pd.DataFrame(PCA_post_text_dataset, 
                                             columns=['PCA_text_1', 'PCA_text_2', 'PCA_text_3'], 
                                             index=X['post_id'])
        return PCA_post_text_dataset

# %%
PCA_post_text_dataset = text_column_processing(df_post[['post_id', 'text']].drop_duplicates(subset='post_id'))
df_post = pd.merge(
    PCA_post_text_dataset,
    df_post,
    on='post_id',
    how='left'
).drop(['text'],axis=1)

df_post
# Out:
#       post_id  PCA_text_1  PCA_text_2  PCA_text_3  topic_covid
# 0           1   -0.118109   -0.202089   -0.091981        False  \
# 1           2   -0.142662   -0.224652   -0.000745        False
# 2           3   -0.104280   -0.152657   -0.088959        False
# 3           4   -0.001531   -0.127431   -0.054667        False
# 4           5    0.055888   -0.104884   -0.004144        False
# ...       ...         ...         ...         ...          ...
# 7018     7315   -0.076983    0.210306    0.128334        False
# 7019     7316   -0.086584    0.131223    0.072740        False
# 7020     7317    0.017890    0.105220   -0.016867        False
# 7021     7318   -0.135336    0.119798    0.011991        False
# 7022     7319    0.009964    0.042797   -0.090252        False
#
#       topic_entertainment  topic_movie  topic_politics  topic_sport
# 0                   False        False           False        False  \
# 1                   False        False           False        False
# 2                   False        False           False        False
# 3                   False        False           False        False
# 4                   False        False           False        False
# ...                   ...          ...             ...          ...
# 7018                False         True           False        False
# 7019                False         True           False        False
# 7020                False         True           False        False
# 7021                False         True           False        False
# 7022                False         True           False        False
#
#       topic_tech
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 7018       False
# 7019       False
# 7020       False
# 7021       False
# 7022       False
#
# [7023 rows x 10 columns]

# %%
df_post.to_sql('rusind899_lesson_22_2', if_exists = 'replace', con=engine) # записываем таблицу
# Out:
# 23

# %%
df_post
# Out:
#       post_id  PCA_text_1  PCA_text_2  PCA_text_3  topic_covid
# 0           1   -0.118109   -0.202089   -0.091981        False  \
# 1           2   -0.142662   -0.224652   -0.000745        False
# 2           3   -0.104280   -0.152657   -0.088959        False
# 3           4   -0.001531   -0.127431   -0.054667        False
# 4           5    0.055888   -0.104884   -0.004144        False
# ...       ...         ...         ...         ...          ...
# 7018     7315   -0.076983    0.210306    0.128334        False
# 7019     7316   -0.086584    0.131223    0.072740        False
# 7020     7317    0.017890    0.105220   -0.016867        False
# 7021     7318   -0.135336    0.119798    0.011991        False
# 7022     7319    0.009964    0.042797   -0.090252        False
#
#       topic_entertainment  topic_movie  topic_politics  topic_sport
# 0                   False        False           False        False  \
# 1                   False        False           False        False
# 2                   False        False           False        False
# 3                   False        False           False        False
# 4                   False        False           False        False
# ...                   ...          ...             ...          ...
# 7018                False         True           False        False
# 7019                False         True           False        False
# 7020                False         True           False        False
# 7021                False         True           False        False
# 7022                False         True           False        False
#
#       topic_tech
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# ...          ...
# 7018       False
# 7019       False
# 7020       False
# 7021       False
# 7022       False
#
# [7023 rows x 10 columns]

# %% [markdown]
# ### Test predict

# %%
user_tab = dff[dff['user_id']==200][['user_id', 'gender', 'age', 'exp_group','country_1.0', 'city_1.0', 'os_iOS',
       'source_organic','userViews','userMeans']]
df_post['user_id']=200
user_tab['timestamp'] = '2021-12-29 21:14:34'
user_tab['timestamp'] = pd.to_datetime(user_tab['timestamp'])
user_tab['hour_of_action'] = user_tab['timestamp'].dt.hour

# %%
user_tab
# Out:
#    user_id  gender   age  exp_group  country_1.0  city_1.0  os_iOS
# 0      200     1.0  34.0        3.0     0.130122  0.174278     0.0  \
#
#    source_organic  userViews  userMeans           timestamp  hour_of_action
# 0             0.0       51.0        6.0 2021-12-29 21:14:34              21

# %%
df_test = pd.merge(
    df_post,
    user_tab,
    on='user_id',
    how='left'
)

df_test
# Out:
#       post_id  PCA_text_1  PCA_text_2  PCA_text_3  topic_covid
# 0           1   -0.118109   -0.202089   -0.091981        False  \
# 1           2   -0.142662   -0.224652   -0.000745        False
# 2           3   -0.104280   -0.152657   -0.088959        False
# 3           4   -0.001531   -0.127431   -0.054667        False
# 4           5    0.055888   -0.104884   -0.004144        False
# ...       ...         ...         ...         ...          ...
# 7018     7315   -0.076983    0.210306    0.128334        False
# 7019     7316   -0.086584    0.131223    0.072740        False
# 7020     7317    0.017890    0.105220   -0.016867        False
# 7021     7318   -0.135336    0.119798    0.011991        False
# 7022     7319    0.009964    0.042797   -0.090252        False
#
#       topic_entertainment  topic_movie  topic_politics  topic_sport
# 0                   False        False           False        False  \
# 1                   False        False           False        False
# 2                   False        False           False        False
# 3                   False        False           False        False
# 4                   False        False           False        False
# ...                   ...          ...             ...          ...
# 7018                False         True           False        False
# 7019                False         True           False        False
# 7020                False         True           False        False
# 7021                False         True           False        False
# 7022                False         True           False        False
#
#       topic_tech  ...   age  exp_group  country_1.0  city_1.0  os_iOS
# 0          False  ...  34.0        3.0     0.130122  0.174278     0.0  \
# 1          False  ...  34.0        3.0     0.130122  0.174278     0.0
# 2          False  ...  34.0        3.0     0.130122  0.174278     0.0
# 3          False  ...  34.0        3.0     0.130122  0.174278     0.0
# 4          False  ...  34.0        3.0     0.130122  0.174278     0.0
# ...          ...  ...   ...        ...          ...       ...     ...
# 7018       False  ...  34.0        3.0     0.130122  0.174278     0.0
# 7019       False  ...  34.0        3.0     0.130122  0.174278     0.0
# 7020       False  ...  34.0        3.0     0.130122  0.174278     0.0
# 7021       False  ...  34.0        3.0     0.130122  0.174278     0.0
# 7022       False  ...  34.0        3.0     0.130122  0.174278     0.0
#
#       source_organic  userViews  userMeans           timestamp  hour_of_action
# 0                0.0       51.0        6.0 2021-12-29 21:14:34              21
# 1                0.0       51.0        6.0 2021-12-29 21:14:34              21
# 2                0.0       51.0        6.0 2021-12-29 21:14:34              21
# 3                0.0       51.0        6.0 2021-12-29 21:14:34              21
# 4                0.0       51.0        6.0 2021-12-29 21:14:34              21
# ...              ...        ...        ...                 ...             ...
# 7018             0.0       51.0        6.0 2021-12-29 21:14:34              21
# 7019             0.0       51.0        6.0 2021-12-29 21:14:34              21
# 7020             0.0       51.0        6.0 2021-12-29 21:14:34              21
# 7021             0.0       51.0        6.0 2021-12-29 21:14:34              21
# 7022             0.0       51.0        6.0 2021-12-29 21:14:34              21
#
# [7023 rows x 22 columns]

# %%
df_test_without = df_test.drop(['user_id','timestamp'],axis = 1)
df_test_without = df_test_without.rename(columns={"country_1.0": "country_1", "city_1.0": "city_1"})

# %%
df_test_without.columns
# Out:
# Index(['post_id', 'PCA_text_1', 'PCA_text_2', 'PCA_text_3', 'topic_covid',
#        'topic_entertainment', 'topic_movie', 'topic_politics', 'topic_sport',
#        'topic_tech', 'gender', 'age', 'exp_group', 'country_1', 'city_1',
#        'os_iOS', 'source_organic', 'userViews', 'userMeans', 'hour_of_action'],
#       dtype='object')

# %%
pred_test_ = pipe.predict(df_test_without[['post_id', 'hour_of_action', 'gender', 'age', 'exp_group', 'PCA_text_1',
       'PCA_text_2', 'PCA_text_3', 'country_1', 'city_1', 'os_iOS',
       'source_organic', 'topic_covid', 'topic_entertainment', 'topic_movie',
       'topic_politics', 'topic_sport', 'topic_tech', 'userViews',
       'userMeans']])

# %%
X = df_test.drop(['user_id', 'timestamp'], axis = 1).rename(columns={"country_1.0": "country_1", "city_1.0": "city_1"})[['post_id', 'hour_of_action', 'gender', 'age', 'exp_group', 'PCA_text_1',
       'PCA_text_2', 'PCA_text_3', 'country_1', 'city_1', 'os_iOS',
       'source_organic', 'topic_covid', 'topic_entertainment', 'topic_movie',
       'topic_politics', 'topic_sport', 'topic_tech', 'userViews',
       'userMeans']]
preds = pipe.predict(X)
y_pred_proba = pipe.predict_proba(X)[:, 1]
X['pred'] = preds
X['pred_proba'] = y_pred_proba
part = X.sort_values(by='pred_proba', ascending=False).head(5)

# %%
answ=post_data[post_data['post_id'].isin([358, 331, 330, 330, 330])]

# %%
answ
for index, row in answ.iterrows():
    print(row.to_dict())
# Out:
